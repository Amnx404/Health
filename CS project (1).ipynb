# %% [markdown]
# # CS Project

# %%
# !pip install plotly==5.1.0
# !pip install -U kaleido
# !pip install nbformat
# Out:
# Requirement already satisfied: plotly==5.1.0 in c:\users\saama\anaconda3\envs\health_cs\lib\site-packages (5.1.0)
# Requirement already satisfied: six in c:\users\saama\anaconda3\envs\health_cs\lib\site-packages (from plotly==5.1.0) (1.16.0)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\saama\anaconda3\envs\health_cs\lib\site-packages (from plotly==5.1.0) (8.0.1)
# Requirement already satisfied: kaleido in c:\users\saama\anaconda3\envs\health_cs\lib\site-packages (0.2.1)
# Collecting nbformat
#   Using cached nbformat-5.1.3-py3-none-any.whl (178 kB)
# Collecting jsonschema!=2.5.0,>=2.4
#   Downloading jsonschema-4.4.0-py3-none-any.whl (72 kB)
# Collecting ipython-genutils
#   Using cached ipython_genutils-0.2.0-py2.py3-none-any.whl (26 kB)
# Requirement already satisfied: jupyter-core in c:\users\saama\anaconda3\envs\health_cs\lib\site-packages (from nbformat) (4.9.1)
# Requirement already satisfied: traitlets>=4.1 in c:\users\saama\anaconda3\envs\health_cs\lib\site-packages (from nbformat) (5.1.1)
# Collecting attrs>=17.4.0
#   Downloading attrs-21.4.0-py2.py3-none-any.whl (60 kB)
# Collecting pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0
#   Downloading pyrsistent-0.18.1-cp39-cp39-win_amd64.whl (61 kB)
# Requirement already satisfied: pywin32>=1.0 in c:\users\saama\anaconda3\envs\health_cs\lib\site-packages (from jupyter-core->nbformat) (303)
# Installing collected packages: pyrsistent, attrs, jsonschema, ipython-genutils, nbformat
# Successfully installed attrs-21.4.0 ipython-genutils-0.2.0 jsonschema-4.4.0 nbformat-5.1.3 pyrsistent-0.18.1

# %%
import plotly as py
import pandas as pd
import plotly.express as px
import json
import numpy
import kaleido
import os
import glob

# %%
INDIA_STATE_GEOMETRY_PATH = "Mapfile\states_india.geojson"
INDIA_STATE_KEYS_PATH = "Mapfile\mapping_key.csv"
DISEASE_RISK_PATH = "Disease_csv"
DISEASE_PATH = ''
MAP_PATH = 'maps'

# %%
def mapping_key_generator():
    df = pd.read_csv("Diseases\AH.csv") #

    india_states = json.load(open('Mapfile\states_india.geojson', 'r'))

    cid = pd.DataFrame(df[['state_mapper','Location']])

    cid.to_csv('Mapfile\mapping_key.csv')

# %%
def utility():
    df['Value per 1000 deaths'] = df['Value'].apply(lambda x: float(x*100))
    df['id'] = df['id'].apply(lambda x: int(x))

# %%
def utility2(india_states):
  state_id_map = {}
  for feature in india_states['features']:
    feature['id'] = feature['properties']['state_code']
    state_id_map[feature['properties']['st_nm']] = feature['id']
  return india_states

# %%
def map_key_adder(csv_to_concat,csv_to_concat_with): 
    #ld = pd.read_csv('Lead.csv')
    MAP_PRINT = pd.merge(csv_to_concat_with,csv_to_concat)
    return MAP_PRINT

# %% [markdown]
# #PLOT

# %%
def map_plot(map_csv,geo_json, map_write_path,names):
    map_csv['id'] = map_csv['state_mapper']
    fig = px.choropleth(map_csv, locations ='id', geojson = geo_json, color = 'Value')
    fig.update_geos(fitbounds = 'locations', visible= False)
    fig.update_layout(
    title_text = names
     # limite map scope to USA
)
    # fig.show()
    fig.write_image(file=os.path.join('maps',f'{names}.png'), format='png')

# %%
def get_all_csv(specific_path):
    path = os.getcwd()
    csv_files = glob.glob(os.path.join(path,specific_path,"*.csv"))
    return csv_files

# %%
CSV_FILES = get_all_csv(DISEASE_RISK_PATH)
cid = pd.read_csv(INDIA_STATE_KEYS_PATH)

india_states = json.load(open('Mapfile\states_india.geojson', 'r'))
india_states = utility2(india_states)
for f in CSV_FILES:
    print(f)
    df = pd.read_csv(f)
    map_print = map_key_adder(df,cid)
    splitf = f.split('\\')
    print(splitf[-1].split('.')[0])
    map_plot(map_print,india_states , MAP_PATH,splitf[-1].split('.')[0])
# Out:
# f:\Code\CS project Health\Health\Disease_csv\Alocoho Use.csv
# Alocoho Use
# f:\Code\CS project Health\Health\Disease_csv\Ambient particulate matter.csv
# Ambient particulate matter
# f:\Code\CS project Health\Health\Disease_csv\Chewing Tobacco.csv
# Chewing Tobacco
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [19], in <module>
#      10 splitf = f.split('\\')
#      11 print(splitf[-1].split('.')[0])
# ---> 12 map_plot(map_print,india_states , MAP_PATH,splitf[-1].split('.')[0])
#
# Input In [18], in map_plot(map_csv, geo_json, map_write_path, names)
#       1 def map_plot(map_csv,geo_json, map_write_path,names):
#       2     map_csv['id'] = map_csv['state_mapper']
# ----> 3     fig = px.choropleth(map_csv, locations ='id', geojson = geo_json, color = 'Value')
#       4     fig.update_geos(fitbounds = 'locations', visible= False)
#       5     fig.update_layout(
#       6     title_text = names
#       7      # limite map scope to USA
#       8 )
#
# File ~\anaconda3\envs\Health_CS\lib\site-packages\plotly\express\_chart_types.py:983, in choropleth(data_frame, lat, lon, locations, locationmode, geojson, featureidkey, color, facet_row, facet_col, facet_col_wrap, facet_row_spacing, facet_col_spacing, hover_name, hover_data, custom_data, animation_frame, animation_group, category_orders, labels, color_discrete_sequence, color_discrete_map, color_continuous_scale, range_color, color_continuous_midpoint, projection, scope, center, fitbounds, basemap_visible, title, template, width, height)
#     943 def choropleth(
#     944     data_frame=None,
#     945     lat=None,
#    (...)
#     977     height=None,
#     978 ):
#     979     """
#     980     In a choropleth map, each row of `data_frame` is represented by a
#     981     colored region mark on a map.
#     982     """
# --> 983     return make_figure(
#     984         args=locals(),
#     985         constructor=go.Choropleth,
#     986         trace_patch=dict(locationmode=locationmode),
#     987     )
#
# File ~\anaconda3\envs\Health_CS\lib\site-packages\plotly\express\_core.py:2118, in make_figure(args, constructor, trace_patch, layout_patch)
#    2109         _set_trace_grid_reference(
#    2110             trace,
#    2111             fig.layout,
#    (...)
#    2114             trace._subplot_col,
#    2115         )
#    2117 # Add traces, layout and frames to figure
# -> 2118 fig.add_traces(frame_list[0]["data"] if len(frame_list) > 0 else [])
#    2119 fig.update_layout(layout_patch)
#    2120 if "template" in args and args["template"] is not None:
#
# File ~\anaconda3\envs\Health_CS\lib\site-packages\plotly\basedatatypes.py:2183, in BaseFigure.add_traces(self, data, rows, cols, secondary_ys, exclude_empty_subplots)
#    2115 """
#    2116 Add traces to the figure
#    2117
#    (...)
#    2179 Figure(...)
#    2180 """
#    2182 # Validate traces
# -> 2183 data = self._data_validator.validate_coerce(data)
#    2185 # Set trace indexes
#    2186 for ind, new_trace in enumerate(data):
#
# File ~\anaconda3\envs\Health_CS\lib\site-packages\_plotly_utils\basevalidators.py:2644, in BaseDataValidator.validate_coerce(self, v, skip_invalid, _validate)
#    2640 for v_el in v:
#    2642     if isinstance(v_el, BaseTraceType):
#    2643         # Clone input traces
# -> 2644         v_el = v_el.to_plotly_json()
#    2646     if isinstance(v_el, dict):
#    2647         v_copy = deepcopy(v_el)
#
# File ~\anaconda3\envs\Health_CS\lib\site-packages\plotly\basedatatypes.py:5550, in BasePlotlyType.to_plotly_json(self)
#    5542 def to_plotly_json(self):
#    5543     """
#    5544     Return plotly JSON representation of object as a Python dict
#    5545
#    (...)
#    5548     dict
#    5549     """
# -> 5550     return deepcopy(self._props if self._props is not None else {})
#
# File ~\anaconda3\envs\Health_CS\lib\copy.py:146, in deepcopy(x, memo, _nil)
#     144 copier = _deepcopy_dispatch.get(cls)
#     145 if copier is not None:
# --> 146     y = copier(x, memo)
#     147 else:
#     148     if issubclass(cls, type):
#
# File ~\anaconda3\envs\Health_CS\lib\copy.py:230, in _deepcopy_dict(x, memo, deepcopy)
#     228 memo[id(x)] = y
#     229 for key, value in x.items():
# --> 230     y[deepcopy(key, memo)] = deepcopy(value, memo)
#     231 return y
#
# File ~\anaconda3\envs\Health_CS\lib\copy.py:146, in deepcopy(x, memo, _nil)
#     144 copier = _deepcopy_dispatch.get(cls)
#     145 if copier is not None:
# --> 146     y = copier(x, memo)
#     147 else:
#     148     if issubclass(cls, type):
#
# File ~\anaconda3\envs\Health_CS\lib\copy.py:230, in _deepcopy_dict(x, memo, deepcopy)
#     228 memo[id(x)] = y
#     229 for key, value in x.items():
# --> 230     y[deepcopy(key, memo)] = deepcopy(value, memo)
#     231 return y
#
#     [... skipping similar frames: deepcopy at line 146 (1 times)]
#
# File ~\anaconda3\envs\Health_CS\lib\copy.py:205, in _deepcopy_list(x, memo, deepcopy)
#     203 append = y.append
#     204 for a in x:
# --> 205     append(deepcopy(a, memo))
#     206 return y
#
#     [... skipping similar frames: deepcopy at line 146 (2 times), _deepcopy_dict at line 230 (1 times)]
#
# File ~\anaconda3\envs\Health_CS\lib\copy.py:230, in _deepcopy_dict(x, memo, deepcopy)
#     228 memo[id(x)] = y
#     229 for key, value in x.items():
# --> 230     y[deepcopy(key, memo)] = deepcopy(value, memo)
#     231 return y
#
#     [... skipping similar frames: deepcopy at line 146 (1 times)]
#
# File ~\anaconda3\envs\Health_CS\lib\copy.py:205, in _deepcopy_list(x, memo, deepcopy)
#     203 append = y.append
#     204 for a in x:
# --> 205     append(deepcopy(a, memo))
#     206 return y
#
#     [... skipping similar frames: deepcopy at line 146 (3 times), _deepcopy_list at line 205 (2 times)]
#
# File ~\anaconda3\envs\Health_CS\lib\copy.py:205, in _deepcopy_list(x, memo, deepcopy)
#     203 append = y.append
#     204 for a in x:
# --> 205     append(deepcopy(a, memo))
#     206 return y
#
# File ~\anaconda3\envs\Health_CS\lib\copy.py:146, in deepcopy(x, memo, _nil)
#     144 copier = _deepcopy_dispatch.get(cls)
#     145 if copier is not None:
# --> 146     y = copier(x, memo)
#     147 else:
#     148     if issubclass(cls, type):
#
# KeyboardInterrupt:

# %%
# !pip install --upgrade nbformat
# !pip install nbformat
# Out:
# Requirement already satisfied: nbformat in c:\users\saama\anaconda3\envs\health_cs\lib\site-packages (5.1.3)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in c:\users\saama\anaconda3\envs\health_cs\lib\site-packages (from nbformat) (4.4.0)
# Requirement already satisfied: traitlets>=4.1 in c:\users\saama\anaconda3\envs\health_cs\lib\site-packages (from nbformat) (5.1.1)
# Requirement already satisfied: jupyter-core in c:\users\saama\anaconda3\envs\health_cs\lib\site-packages (from nbformat) (4.9.1)
# Requirement already satisfied: ipython-genutils in c:\users\saama\anaconda3\envs\health_cs\lib\site-packages (from nbformat) (0.2.0)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\saama\anaconda3\envs\health_cs\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat) (21.4.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in c:\users\saama\anaconda3\envs\health_cs\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat) (0.18.1)
# Requirement already satisfied: pywin32>=1.0 in c:\users\saama\anaconda3\envs\health_cs\lib\site-packages (from jupyter-core->nbformat) (303)
# Requirement already satisfied: nbformat in c:\users\saama\anaconda3\envs\health_cs\lib\site-packages (5.1.3)
# Requirement already satisfied: traitlets>=4.1 in c:\users\saama\anaconda3\envs\health_cs\lib\site-packages (from nbformat) (5.1.1)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in c:\users\saama\anaconda3\envs\health_cs\lib\site-packages (from nbformat) (4.4.0)
# Requirement already satisfied: jupyter-core in c:\users\saama\anaconda3\envs\health_cs\lib\site-packages (from nbformat) (4.9.1)
# Requirement already satisfied: ipython-genutils in c:\users\saama\anaconda3\envs\health_cs\lib\site-packages (from nbformat) (0.2.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in c:\users\saama\anaconda3\envs\health_cs\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat) (0.18.1)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\saama\anaconda3\envs\health_cs\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat) (21.4.0)
# Requirement already satisfied: pywin32>=1.0 in c:\users\saama\anaconda3\envs\health_cs\lib\site-packages (from jupyter-core->nbformat) (303)
